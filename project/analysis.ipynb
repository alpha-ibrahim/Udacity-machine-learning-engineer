# %%
import xlrd 
import pandas as pd
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
# !pwd
# !ls combined_reports/2016/subject_mark/term4/
# Out:
# /home/alpha/Courses/Udacity/Machine_learning/Udacity-machine-learning-engineer/project
# DDD SUBJECT MARK SCHEDULE_CIRCUIT 19_2016_TERM4_mathematics.XLSX

# %%
grade_12 = pd.read_excel('combined_reports/2016/DDD LEARNER NSC PERFORMANCE REPORT_CIRCUIT 19_FOR_2016.XLSX', header=2)

# %%
mathematics_gr12_term4 = pd.read_excel("combined_reports/2016/subject_mark/term4/DDD SUBJECT MARK SCHEDULE_CIRCUIT 19_2016_TERM4_mathematics.XLSX", header = 2)

# %%
mathematics_gr12_term4.head()
# Out:
#                                                                                                      Term 1  \
# Number District    EMISCode  Institution Accession Number Learner Name  Gender Grade     Exam/Test Mark (%)
# NaN    District 12 000000035 School 105  NaN              NaN           NaN    Grade 12                 100
# 1      District 12 000000035 School 105  1951437          1951437, John Male   Grade 12             29.3333
# 2      District 12 000000035 School 105  73346            73346, John   Male   Grade 12                  64
# 3      District 12 000000035 School 105  73420            73420, Mary   Female Grade 12             60.6667
#
#                                                                                                       NaN  \
# Number District    EMISCode  Institution Accession Number Learner Name  Gender Grade     Report Marks (%)
# NaN    District 12 000000035 School 105  NaN              NaN           NaN    Grade 12               100
# ...

# %%
mathematics_gr12_term4.columns
# Out:
# Index([                   u'Term 1',                         None,
#                           u'Term 2',                    u'None.1',
#                           u'Term 3',                    u'None.2',
#                           u'Term 4',                    u'None.3',
#        u'Term 1 - Task Achievement',                    u'None.4',
#                           u'None.5',                    u'None.6',
#                           u'None.7',                    u'None.8',
#                           u'None.9', u'Term 2 - Task Achievement',
#                          u'None.10',                   u'None.11',
#                          u'None.12',                   u'None.13',
#                          u'None.14',                   u'None.15',
#        u'Term 3 - Task Achievement',                   u'None.16',
#                          u'None.17',                   u'None.18',
#                          u'None.19',                   u'None.20',
# ...

# %%
# add average mark
mathematics_gr12_term4['ave_mark'] =
# Out:
#   File "<ipython-input-7-9168e6592eab>", line 2
#     mathematics_gr12_term4['ave_mark'] =
#                                          ^
# SyntaxError: invalid syntax

# %%
math_term1_mark = pd.DataFrame(mathematics_gr12_term4['Term 1'])
math_term2_mark = pd.DataFrame(mathematics_gr12_term4['Term 2'])
math_term3_mark = pd.DataFrame(mathematics_gr12_term4['Term 3'])
math_term4_mark = pd.DataFrame(mathematics_gr12_term4['Term 4'])
math_term1_mark.reset_index(inplace = True)
math_term2_mark.reset_index(inplace = True)
math_term3_mark.reset_index(inplace = True)
math_term4_mark.reset_index(inplace = True)

# %%
math_term1_mark.columns = math_term1_mark.iloc[0].values
math_term2_mark.columns = math_term2_mark.iloc[0].values
math_term3_mark.columns = math_term3_mark.iloc[0].values
math_term4_mark.columns = math_term4_mark.iloc[0].values

# %%
math_term1_mark.head()
# Out:
#    Number     District   EMISCode  Institution  Accession Number  \
# 0  Number     District   EMISCode  Institution  Accession Number
# 1     NaN  District 12  000000035   School 105               NaN
# 2       1  District 12  000000035   School 105           1951437
# 3       2  District 12  000000035   School 105             73346
# 4       3  District 12  000000035   School 105             73420
#
#     Learner Name  Gender     Grade  Exam/Test Mark (%)
# 0   Learner Name  Gender     Grade  Exam/Test Mark (%)
# 1            NaN     NaN  Grade 12                 100
# 2  1951437, John    Male  Grade 12             29.3333
# 3    73346, John    Male  Grade 12                  64
# 4    73420, Mary  Female  Grade 12             60.6667

# %%
math_term1_mark[["Accession Number", "Exam/Test Mark (%)" ]]
# Out:
#      Accession Number  Exam/Test Mark (%)
# 0    Accession Number  Exam/Test Mark (%)
# 1                 NaN                 100
# 2             1951437             29.3333
# 3               73346                  64
# 4               73420             60.6667
# 5               73689             55.3333
# 6               74098             61.3333
# 7               74223             40.6667
# 8               74355             59.3333
# 9               74420                  62
# 10              74829                  50
# 11              75016             53.3333
# 12              75020                  66
# 13              75029             57.3333
# 14              75059             28.6667
# 15              75062             58.6667
# 16              75072             63.3333
# 17              75074             49.3333
# 18              75090             76.6667
# 19              75092             67.3333
# 20              75098                  32
# ...

# %%
test
# Out:
#      Number     District   EMISCode  Institution  Accession Number  \
# 0    Number     District   EMISCode  Institution  Accession Number
# 1       NaN  District 12  000000035   School 105               NaN
# 2         1  District 12  000000035   School 105           1951437
# 3         2  District 12  000000035   School 105             73346
# 4         3  District 12  000000035   School 105             73420
# 5         4  District 12  000000035   School 105             73689
# 6         5  District 12  000000035   School 105             74098
# 7         6  District 12  000000035   School 105             74223
# 8         7  District 12  000000035   School 105             74355
# 9         8  District 12  000000035   School 105             74420
# 10        9  District 12  000000035   School 105             74829
# 11       10  District 12  000000035   School 105             75016
# 12       11  District 12  000000035   School 105             75020
# ...

# %%
test.columns  = test.iloc[0].values

# %%
test
# Out:
#      Number     District   EMISCode  Institution  Accession Number  \
# 0    Number     District   EMISCode  Institution  Accession Number
# 1       NaN  District 12  000000035   School 105               NaN
# 2         1  District 12  000000035   School 105           1951437
# 3         2  District 12  000000035   School 105             73346
# 4         3  District 12  000000035   School 105             73420
# 5         4  District 12  000000035   School 105             73689
# 6         5  District 12  000000035   School 105             74098
# 7         6  District 12  000000035   School 105             74223
# 8         7  District 12  000000035   School 105             74355
# 9         8  District 12  000000035   School 105             74420
# 10        9  District 12  000000035   School 105             74829
# 11       10  District 12  000000035   School 105             75016
# 12       11  District 12  000000035   School 105             75020
# ...

# %%
learner_chart_g11 = pd.read_excel('combined_reports/2015/DDD LEARNER CHART_CIRCUIT_CIRCUIT 19 - 11_2015_TERM4.XLSX', header=5)

# %%
math_term2_mark
# Out:
# Number  District     EMISCode   Institution  Accession Number  Learner Name   Gender  Grade       Exam/Test Mark (%)
# NaN     District 12  000000035  School 105   NaN               NaN            NaN     Grade 12                   100
# 1       District 12  000000035  School 105   1951437           1951437, John  Male    Grade 12                     8
# 2       District 12  000000035  School 105   73346             73346, John    Male    Grade 12               28.6667
# 3       District 12  000000035  School 105   73420             73420, Mary    Female  Grade 12                    26
# 4       District 12  000000035  School 105   73689             73689, Mary    Female  Grade 12               21.3333
# 5       District 12  000000035  School 105   74098             74098, John    Male    Grade 12               10.3333
# 6       District 12  000000035  School 105   74223             74223, Mary    Female  Grade 12                    10
# ...

# %%
learner_chart_g11.head()
# Out:
#    Number  EMISCode Institution  Accession\n Number   Learner Name Gender  \
# 0     NaN        35  School 105             1606841  1606841, John      M
# 1     NaN        35  School 105             1606841  1606841, John      M
# 2     NaN        35  School 105             1606841  1606841, John      M
# 3     NaN        35  School 105             1606841  1606841, John      M
# 4     NaN        35  School 105             1606841  1606841, John      M
#
#    Learner Average Required Subjects  Learner Average (All subjects)  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#    Accounting(%)  Agricultural Sciences(%) ...   (%).19  No. DAYS ABSENT  \
# ...

# %%
learner_chart_g11.Number
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
#         ..
# 5018   NaN
# 5019   NaN
# 5020   NaN
# 5021   NaN
# 5022   NaN
# 5023   NaN
# 5024   NaN
# 5025   NaN
# 5026   NaN
# 5027   NaN
# 5028   NaN
# 5029   NaN
# 5030   NaN
# 5031   NaN
# 5032   NaN
# 5033   NaN
# 5034   NaN
# 5035   NaN
# 5036   NaN
# 5037   NaN
# 5038   NaN
# 5039   NaN
# 5040   NaN
# 5041   NaN
# 5042   NaN
# 5043   NaN
# 5044   NaN
# 5045   NaN
# 5046   NaN
# 5047   NaN
# Name: Number, Length: 5048, dtype: float64

# %%
learner_chart_g11 = learner_chart_g11.rename(columns = {'Learner Name':'Learner'})

# %%
learner_chart_g11.head()
# Out:
#    Number  EMISCode Institution  Accession\n Number        Learner Gender  \
# 0     NaN        35  School 105             1606841  1606841, John      M
# 1     NaN        35  School 105             1606841  1606841, John      M
# 2     NaN        35  School 105             1606841  1606841, John      M
# 3     NaN        35  School 105             1606841  1606841, John      M
# 4     NaN        35  School 105             1606841  1606841, John      M
#
#    Learner Average Required Subjects  Learner Average (All subjects)  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#    Accounting(%)  Agricultural Sciences(%) ...   (%).19  No. DAYS ABSENT  \
# ...

# %%
learner_information_g11 = pd.read_excel('combined_reports/2015/DDD LEARNER INFORMATION_CIRCUIT_CIRCUIT 19 - 2015_TERM4.XLSX', header=3)

# %%
learner_information_g11.head()
# Out:
#   Province Name District Name Circuit Name  EMIS Code      School  \
# 0    Province 4   District 12   Circuit 19         35  School 105
# 1    Province 4   District 12   Circuit 19         35  School 105
# 2    Province 4   District 12   Circuit 19         35  School 105
# 3    Province 4   District 12   Circuit 19         35  School 105
# 4    Province 4   District 12   Circuit 19         35  School 105
#
#          Learner     Grade  Age      Age vs Grade  Gender      Ethnicity  NaN  \
# 0  1606786, John  Grade 10   19  3 year(s) behind    Male  African/Black  NaN
# 1  1606811, Mary  Grade 10   19  3 year(s) behind  Female  African/Black  NaN
# 2  1606816, Mary  Grade 10   16          on track  Female  African/Black  NaN
# 3  1606834, Mary  Grade 10   18  2 year(s) behind  Female  African/Black  NaN
# 4  1606848, John  Grade 10   23  7 year(s) behind    Male  African/Black  NaN
#
#   Attendance
# 0       100%
# 1       100%
# 2       100%
# 3       100%
# 4       100%

# %%
combined = pd.merge(learner_chart_g11, learner_information_g11, how = 'inner', on = 'Learner')

# %%
len(learner_chart_g11)
# Out:
# 5048

# %%
len(learner_information_g11)
# Out:
# 1930

# %%
len(combined)
# Out:
# 5048

# %%
combined.head()
# Out:
#    Number  EMISCode Institution  Accession\n Number        Learner Gender_x  \
# 0     NaN        35  School 105             1606841  1606841, John        M
# 1     NaN        35  School 105             1606841  1606841, John        M
# 2     NaN        35  School 105             1606841  1606841, John        M
# 3     NaN        35  School 105             1606841  1606841, John        M
# 4     NaN        35  School 105             1606841  1606841, John        M
#
#    Learner Average Required Subjects  Learner Average (All subjects)  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#    Accounting(%)  Agricultural Sciences(%)     ...      Circuit Name  \
# ...

# %%
combined[combined.Learner == "1951437, John"]
# Out:
#     Number  EMISCode Institution  Accession\n Number        Learner Gender_x  \
# 66     NaN        35  School 105             1951437  1951437, John        M
# 67     NaN        35  School 105             1951437  1951437, John        M
# 68     NaN        35  School 105             1951437  1951437, John        M
# 69     NaN        35  School 105             1951437  1951437, John        M
# 70     NaN        35  School 105             1951437  1951437, John        M
# 71     NaN        35  School 105             1951437  1951437, John        M
#
#     Learner Average Required Subjects  Learner Average (All subjects)  \
# 66                                NaN                             NaN
# 67                                NaN                             NaN
# 68                                NaN                             NaN
# 69                                NaN                             NaN
# 70                                NaN                             NaN
# ...
